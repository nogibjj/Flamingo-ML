# %%
import pandas as pd
import numpy as np

merged = pd.read_csv("crypto_news/bitcoin_news_sentiment_hourly.csv")

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1799 entries, 0 to 1798
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          1799 non-null   int64
#  1   date_dt             1799 non-null   object
#  2   date_hr             1799 non-null   int64
#  3   positive_count      1799 non-null   float64
#  4   negative_count      1799 non-null   float64
#  5   neutral_count       1799 non-null   float64
#  6   positive_avg_score  1799 non-null   float64
#  7   negative_avg_score  1799 non-null   float64
#  8   neutral_avg_score   1799 non-null   float64
#  9   total_news_count    1799 non-null   float64
#  10  total_news_score    1799 non-null   float64
#  11  signal              1069 non-null   float64
# dtypes: float64(9), int64(2), object(1)
# memory usage: 168.8+ KB

# %%
merged.drop(columns=["date_dt", "Unnamed: 0", "date_hr"], inplace=True)
merged.columns = merged.columns.str.replace("_", " ")
merged.head()
# Out:
#    positive count  negative count  neutral count  positive avg score  \
# 0             1.0             0.0            0.0            0.909999
# 1             0.0             0.0            1.0            0.000000
# 2             1.0             0.0            1.0            0.958578
# 3             2.0             0.0            0.0            0.916790
# 4             0.0             0.0            1.0            0.000000
#
#    negative avg score  neutral avg score  total news count  total news score  \
# 0                 0.0           0.000000               1.0          0.909999
# 1                 0.0           0.959562               1.0          0.000000
# 2                 0.0           0.586960               2.0          0.958578
# 3                 0.0           0.000000               2.0          1.833581
# 4                 0.0           0.974475               1.0          0.000000
#
#    signal
# 0     1.0
# 1     NaN
# 2     1.0
# 3     1.0
# 4     NaN

# %%
axes = merged.hist(figsize=(15, 15), layout=(3, 3))
for ax in axes.flatten():
    ax.set_xlabel("Value")
    ax.set_ylabel("Frequency")
