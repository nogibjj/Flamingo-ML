# %%
from IPython.display import Audio


def all_done():
    # Replace 'your_audio_file.wav' with the path to your audio file
    return Audio("Shnappi 2.wav", autoplay=True)


all_done()
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from IPython.display import display, Javascript


def play_audio_with_js(audio_path):
    js_code = f"""
    var audio = new Audio("{audio_path}");
    audio.play();
    """
    display(Javascript(js_code))


play_audio_with_js("Shnappi 2.wav")

# %%
import numpy as np
from IPython.display import Audio, display


def beep():
    framerate = 44100
    duration = 0.2  # seconds
    freq = 440  # Hz
    t = np.linspace(0, duration, int(framerate * duration))
    data = np.sin(2 * np.pi * freq * t)
    display(Audio(data, rate=framerate, autoplay=True))


beep()
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from IPython.display import display, Markdown


def notify_end():
    display(Markdown("**🚀 Cell Execution Finished! 🚀**"))


# Your code
notify_end()
# Out:
# **🚀 Cell Execution Finished! 🚀**

# %%
import os


def notify_system():
    os.system(
        """
              osascript -e 'display notification "Cell execution finished" with title "VS Code"'
              """
    )


notify_system()

# %%
################################
# Load the data
################################
from sklearn import datasets
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
import numpy as np
import pandas as pd

# load dataset
digits = datasets.load_digits()
n_sample = digits.target.shape[0]
n_feature = digits.images.shape[1] * digits.images.shape[2]
X_digits = np.zeros((n_sample, n_feature))
for i in range(n_sample):
    X_digits[i, :] = digits.images[i, :, :].flatten()
y_digits = digits.target

# %%
pd.DataFrame(X_digits).describe()
# Out:
#            0            1            2            3            4   \
# count  1797.0  1797.000000  1797.000000  1797.000000  1797.000000
# mean      0.0     0.303840     5.204786    11.835838    11.848080
# std       0.0     0.907192     4.754826     4.248842     4.287388
# min       0.0     0.000000     0.000000     0.000000     0.000000
# 25%       0.0     0.000000     1.000000    10.000000    10.000000
# 50%       0.0     0.000000     4.000000    13.000000    13.000000
# 75%       0.0     0.000000     9.000000    15.000000    15.000000
# max       0.0     8.000000    16.000000    16.000000    16.000000
#
#                 5            6            7            8            9   ...  \
# count  1797.000000  1797.000000  1797.000000  1797.000000  1797.000000  ...
# mean      5.781859     1.362270     0.129661     0.005565     1.993879  ...
# std       5.666418     3.325775     1.037383     0.094222     3.196160  ...
# ...

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_digits_standardized = pd.DataFrame(scaler.fit_transform(X_digits))
X_digits_standardized.describe()
# Out:
#            0             1             2             3             4   \
# count  1797.0  1.797000e+03  1.797000e+03  1.797000e+03  1.797000e+03
# mean      0.0 -6.326480e-17  7.908099e-17  3.163240e-17 -5.535670e-17
# std       0.0  1.000278e+00  1.000278e+00  1.000278e+00  1.000278e+00
# min       0.0 -3.350165e-01 -1.094937e+00 -2.786437e+00 -2.764242e+00
# 25%       0.0 -3.350165e-01 -8.845657e-01 -4.321998e-01 -4.311703e-01
# 50%       0.0 -3.350165e-01 -2.534522e-01  2.740715e-01  2.687512e-01
# 75%       0.0 -3.350165e-01  7.984036e-01  7.449191e-01  7.353655e-01
# max       0.0  8.485857e+00  2.271002e+00  9.803428e-01  9.686727e-01
#
#                  5            6             7             8             9   \
# count  1.797000e+03  1797.000000  1.797000e+03  1.797000e+03  1.797000e+03
# mean  -5.535670e-17     0.000000  1.581620e-17 -2.767835e-17  2.372430e-17
# std    1.000278e+00     1.000278  1.000278e+00  1.000278e+00  1.000278e+00
# ...

# %%
pca_all = PCA(n_components=None)
pca_all.fit(X_digits_standardized)

cumulative_variance_ratio = np.cumsum(pca_all.explained_variance_ratio_)
unexplained_variance = 1 - cumulative_variance_ratio[1]
print(f"Unexplained variance by first two components: {unexplained_variance}")
# Out:
# Unexplained variance by first two components: 0.7840502949916727
